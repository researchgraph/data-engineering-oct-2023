# %% [markdown]
# # Batches 2 Neo4j
# Load batches of JSON data and populate in the Neo4j graph db using apoc procedure.
#
# Aland Astudillo - 2023-10-05

# %%
from neo4j import GraphDatabase

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", "clavecita"), database='papers3')

# %%
session = driver.session()

# %%
query_paper = """
CALL apoc.load.json("file:///batches/batch_51.json")
YIELD value
WITH value
MERGE (paper:PAPER {name: value.title, code: value.id, doi: value.doi, url: value.url})
RETURN paper LIMIT 30
"""

# %%
# run the query to load a sample of papers
results = session.run(query_paper)

# %%
results.data()
# Out:
# [{'paper': {'code': '10.1145/22339.22340',
#    'name': ['The information lens: an intelligent system for information sharing in organizations'],
#    'url': 'http://dx.doi.org/10.1145/22339.22340',
#    'doi': '10.1145/22339.22340'}},
#  {'paper': {'code': '10.1108/imds-05-2017-0214',
#    'name': ['Understanding adoption of intelligent personal assistants'],
#    'url': 'http://dx.doi.org/10.1108/imds-05-2017-0214',
#    'doi': '10.1108/imds-05-2017-0214'}},
#  {'paper': {'code': '10.3897/biss.2.25268',
#    'name': ['Supporting citizen scientists with automatic species identification using deep learning image recognition models'],
#    'url': 'http://dx.doi.org/10.3897/biss.2.25268',
#    'doi': '10.3897/biss.2.25268'}},
#  {'paper': {'code': '10.1108/tqm-10-2019-0250',
#    'name': ['New perspectives from technology adoption in senior cohousing facilities'],
#    'url': 'http://dx.doi.org/10.1108/tqm-10-2019-0250',
#    'doi': '10.1108/tqm-10-2019-0250'}},
#  {'paper': {'code': '10.17223/22220836/39/6',
#    'name': ['SMART AS A PARADIGM OF MODERN CULTURE'],
#    'url': 'http://dx.doi.org/10.17223/22220836/39/6',
#    'doi': '10.17223/22220836/39/6'}},
#  {'paper': {'code': '10.3389/fcvm.2020.609976',
#    'name': ['Detection of Left Atrial Enlargement Using a Convolutional Neural Network-Enabled Electrocardiogram'],
#    'url': 'http://dx.doi.org/10.3389/fcvm.2020.609976',
#    'doi': '10.3389/fcvm.2020.609976'}},
#  {'paper': {'code': '10.1108/bfj-08-2021-0905',
#    'name': ["Exploring agricultural entrepreneurship and new technologies: academic and practitioners' views"],
#    'url': 'http://dx.doi.org/10.1108/bfj-08-2021-0905',
#    'doi': '10.1108/bfj-08-2021-0905'}},
#  {'paper': {'code': '10.33296/2707-0654-11(22)-11',
#    'name': ['Інноваційні інформаційні технології в підготовці та управлінні персоналом'],
#    'url': 'http://dx.doi.org/10.33296/2707-0654-11(22)-11',
#    'doi': '10.33296/2707-0654-11(22)-11'}},
#  {'paper': {'code': '10.3389/fpsyt.2022.789504',
#    'name': ['Characteristics of High Suicide Risk Messages From Users of a Social Network—Sina Weibo “Tree Hole”'],
#    'url': 'http://dx.doi.org/10.3389/fpsyt.2022.789504',
#    'doi': '10.3389/fpsyt.2022.789504'}},
#  {'paper': {'code': '10.2523/iptc-22134-ea',
#    'name': ['Utilizing Immersive Technology to Enhance Plant Operations and Speed Up Knowledge Transfer'],
#    'url': 'http://dx.doi.org/10.2523/iptc-22134-ea',
#    'doi': '10.2523/iptc-22134-ea'}},
#  {'paper': {'code': '10.31235/osf.io/3ftqy',
#    'name': ['Rule of Algorithm in Lv Shi Chun Qiu: Lessons To Learn'],
#    'url': 'http://dx.doi.org/10.31235/osf.io/3ftqy',
#    'doi': '10.31235/osf.io/3ftqy'}},
#  {'paper': {'code': '10.3389/fonc.2022.838039',
#    'name': ['Dosimetric Impact of Inter-Fraction Variability in the Treatment of Breast Cancer: Towards New Criteria to Evaluate the Appropriateness of Online Adaptive Radiotherapy'],
#    'url': 'http://dx.doi.org/10.3389/fonc.2022.838039',
#    'doi': '10.3389/fonc.2022.838039'}},
#  {'paper': {'code': '10.46720/f2021-acm-117',
#    'name': ['Enhancing the acceptance of future automated vehicles through understanding the emotional state of passengers'],
#    'url': 'http://dx.doi.org/10.46720/f2021-acm-117',
#    'doi': '10.46720/f2021-acm-117'}},
#  {'paper': {'code': '10.1108/aci-02-2022-0048',
#    'name': ['Autonomous cycles of data analysis tasks for innovation processes in MSMEs'],
#    'url': 'http://dx.doi.org/10.1108/aci-02-2022-0048',
#    'doi': '10.1108/aci-02-2022-0048'}},
#  {'paper': {'code': '10.3389/fphy.2022.897710',
#    'name': ['Dosimetric Evaluation of Dose Calculation Uncertainties for MR-Only Approaches in Prostate MR-Guided Radiotherapy'],
#    'url': 'http://dx.doi.org/10.3389/fphy.2022.897710',
#    'doi': '10.3389/fphy.2022.897710'}},
#  {'paper': {'code': '10.1108/lht-10-2022-0486',
#    'name': ['Applications of metaverse-related technologies in the services of US urban libraries'],
#    'url': 'http://dx.doi.org/10.1108/lht-10-2022-0486',
#    'doi': '10.1108/lht-10-2022-0486'}},
#  {'paper': {'code': '10.32362/2500-316x-2023-11-2-33-49',
#    'name': ['Models and methods for analyzing complex networks and social network structures'],
#    'url': 'http://dx.doi.org/10.32362/2500-316x-2023-11-2-33-49',
#    'doi': '10.32362/2500-316x-2023-11-2-33-49'}},
#  {'paper': {'code': '10.33108/galicianvisnyk_tntu2023.02.096',
#    'name': ['Application of information technologies in business-analysis of organizations activity under crisis conditions'],
#    'url': 'http://dx.doi.org/10.33108/galicianvisnyk_tntu2023.02.096',
#    'doi': '10.33108/galicianvisnyk_tntu2023.02.096'}},
#  {'paper': {'code': '10.1108/josm-08-2019-0254',
#    'name': ['From words to pixels: text and image mining methods for service research'],
#    'url': 'http://dx.doi.org/10.1108/josm-08-2019-0254',
#    'doi': '10.1108/josm-08-2019-0254'}},
#  {'paper': {'code': '10.1186/s12903-020-01114-6',
#    'name': ['Deep learning-based dental plaque detection on primary teeth: a comparison with clinical assessments'],
#    'url': 'http://dx.doi.org/10.1186/s12903-020-01114-6',
#    'doi': '10.1186/s12903-020-01114-6'}},
#  {'paper': {'code': '10.1200/jco.2020.38.15_suppl.e23529',
#    'name': ['Prediction of histologic and molecular subsets of soft tissue sarcoma using deep learning.'],
#    'url': 'http://dx.doi.org/10.1200/jco.2020.38.15_suppl.e23529',
#    'doi': '10.1200/jco.2020.38.15_suppl.e23529'}},
#  {'paper': {'code': '10.2196/19867',
#    'name': ['Pediatric Mental and Behavioral Health in the Period of Quarantine and Social Distancing With COVID-19'],
#    'url': 'http://dx.doi.org/10.2196/19867',
#    'doi': '10.2196/19867'}},
#  {'paper': {'code': '10.1101/2021.01.29.21250745',
#    'name': ['Successful reboot of high-performance sporting activities by Japanese national women’s handball team in Tokyo, 2020 during the COVID-19 pandemic: An initiative by Japan Sports-Cyber Physical System (JS-CPS) of Sports Research Innovation Project (SRIP)'],
#    'url': 'http://dx.doi.org/10.1101/2021.01.29.21250745',
#    'doi': '10.1101/2021.01.29.21250745'}},
#  {'paper': {'code': '10.1371/journal.pone.0237285',
#    'name': ['PI Prob: A risk prediction and clinical guidance system for evaluating patients with recurrent infections'],
#    'url': 'http://dx.doi.org/10.1371/journal.pone.0237285',
#    'doi': '10.1371/journal.pone.0237285'}},
#  {'paper': {'code': '10.1093/ecco-jcc/jjab075.007',
#    'name': ['OP08 Automatic detection of enteric ulcers and erosions in capsule endoscopy using a convolutional neural network'],
#    'url': 'http://dx.doi.org/10.1093/ecco-jcc/jjab075.007',
#    'doi': '10.1093/ecco-jcc/jjab075.007'}},
#  {'paper': {'code': '10.1017/s0033291721002294',
#    'name': ['World Trade Center responders in their own words: predicting PTSD symptom trajectories with AI-based language analyses of interviews'],
#    'url': 'http://dx.doi.org/10.1017/s0033291721002294',
#    'doi': '10.1017/s0033291721002294'}},
#  {'paper': {'code': '10.30632/spwla-2021-0099',
#    'name': ['AN ENHANCED METHOD FOR CRACK EVALUATION UTILIZING NEUTRON GAMMA TRACER IMAGING LOGGING TECHNOLOGY IN CARBONATE RESERVOIR'],
#    'url': 'http://dx.doi.org/10.30632/spwla-2021-0099',
#    'doi': '10.30632/spwla-2021-0099'}},
#  {'paper': {'code': '10.1182/blood-2021-152566',
#    'name': ['Prognosis and Therapeutic Response Transfer Learning Model for Multiple Myeloma'],
#    'url': 'http://dx.doi.org/10.1182/blood-2021-152566',
#    'doi': '10.1182/blood-2021-152566'}},
#  {'paper': {'code': '10.1200/jco.2022.40.6_suppl.222',
#    'name': ['Development and validation of a prognostic AI biomarker using multi-modal deep learning with digital histopathology in localized prostate cancer on NRG Oncology phase III clinical trials.'],
#    'url': 'http://dx.doi.org/10.1200/jco.2022.40.6_suppl.222',
#    'doi': '10.1200/jco.2022.40.6_suppl.222'}},
#  {'paper': {'code': '10.47992/ijcsbe.2581.6942.0162',
#    'name': ['Seven Pillars of Inclusive Ecosystem -Transforming Healthcare Special reference to MSME &amp; SME sectors'],
#    'url': 'http://dx.doi.org/10.47992/ijcsbe.2581.6942.0162',
#    'doi': '10.47992/ijcsbe.2581.6942.0162'}}]

# %%
# go through the JSON file batches

# define the number of iterations - has to be related to the number of total batches files
startpoint = 21
niter = 51 #51 

# query to add papers
query_p2 = """
YIELD value
WITH value
MERGE (paper:PAPER {name: value.title, code: value.id, doi: value.doi, url: value.url})
RETURN paper LIMIT 30
"""

# query to add organisations
query_p3 = """
YIELD value
WITH value.author AS authors
UNWIND authors AS au
WITH au
WHERE au<>"no"
UNWIND au.affiliation as affiliation
WITH affiliation.name as name
WHERE name IS NOT NULL 
MERGE (o:ORGANISATION {name: name})
RETURN o LIMIT 30
"""

# query to add authors
query_p4 = """
YIELD value
WITH value.author AS authors, value.id as code
UNWIND authors AS au
WITH au, code
WHERE au<>"no"
UNWIND au.affiliation as affiliation
MERGE (a:AUTHOR {name: COALESCE(au.given ,"") + ',' + COALESCE(au.family ,"")}) ON CREATE SET a.given = au.given, a.family = au.family, a.affiliation = affiliation.name           
MERGE (p:PAPER {code: code})
MERGE (p)-[:WRITTEN_BY {score: 1}]->(a)
WITH affiliation.name as affiname, p, a
WHERE affiname IS NOT NULL 
MERGE (o:ORGANISATION {name: affiname})
MERGE (a)-[:IS_PART_OF {score: 1}]->(o)
RETURN a, p, o LIMIT 30
"""

for i in range(startpoint, niter): # 1 and 2 ready, go from 2 to 51
    # add papers
    query_p1 = 'CALL apoc.load.json("file:///batches/batch_{}.json")'.format(i+1)
    print('Start Iteration ' + str(i+1) + ', File: ' + query_p1)

    query_paper = query_p1 + query_p2
    results1 = session.run(query_paper)
    print ('Papers ready')
    # add organisations
    query_organisation = query_p1 + query_p3
    results2 = session.run(query_organisation) # organisations without name are skiped (organisation.name =null)
    print ('Organisations ready')
    # add authors
    query_authors = query_p1 + query_p4
    results3 = session.run(query_authors) # authors when organisation without name are skiped (organisation.name =null)
    print ('Authors ready')
    #print('Iteration ' + str(i+1) + ', File: ' + query_p1, end='\r')
    print('End Iteration ' + str(i+1) + ', File: ' + query_p1)
# Out:
# Iteration 4, File: CALL apoc.load.json("file:///batches/batch_4.json")
# Iteration 5, File: CALL apoc.load.json("file:///batches/batch_5.json")
# Iteration 6, File: CALL apoc.load.json("file:///batches/batch_6.json")
# Iteration 7, File: CALL apoc.load.json("file:///batches/batch_7.json")
# Iteration 8, File: CALL apoc.load.json("file:///batches/batch_8.json")
# Iteration 9, File: CALL apoc.load.json("file:///batches/batch_9.json")
# Iteration 10, File: CALL apoc.load.json("file:///batches/batch_10.json")
# Iteration 11, File: CALL apoc.load.json("file:///batches/batch_11.json")
# Iteration 12, File: CALL apoc.load.json("file:///batches/batch_12.json")
# Iteration 13, File: CALL apoc.load.json("file:///batches/batch_13.json")
# Iteration 14, File: CALL apoc.load.json("file:///batches/batch_14.json")
# Iteration 15, File: CALL apoc.load.json("file:///batches/batch_15.json")
# Iteration 16, File: CALL apoc.load.json("file:///batches/batch_16.json")
# Iteration 17, File: CALL apoc.load.json("file:///batches/batch_17.json")
# Iteration 18, File: CALL apoc.load.json("file:///batches/batch_18.json")
# Iteration 19, File: CALL apoc.load.json("file:///batches/batch_19.json")
# Iteration 20, File: CALL apoc.load.json("file:///batches/batch_20.json")
# Iteration 21, File: CALL apoc.load.json("file:///batches/batch_21.json")
# Iteration 22, File: CALL apoc.load.json("file:///batches/batch_22.json")
# Iteration 23, File: CALL apoc.load.json("file:///batches/batch_23.json")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ALANDASTU\Dropbox\WORKING\neo4j_jupyters\Batches2Neo4j.ipynb Cell 7 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/ALANDASTU/Dropbox/WORKING/neo4j_jupyters/Batches2Neo4j.ipynb#W6sZmlsZQ%3D%3D?line=48'>49</a> query_p1 = 'CALL apoc.load.json("file:///batches/batch_{}.json")'.format(i+1)
#      <a href='vscode-notebook-cell:/c%3A/Users/ALANDASTU/Dropbox/WORKING/neo4j_jupyters/Batches2Neo4j.ipynb#W6sZmlsZQ%3D%3D?line=49'>50</a> query_paper = query_p1 + query_p2
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ALANDASTU/Dropbox/WORKING/neo4j_jupyters/Batches2Neo4j.ipynb#W6sZmlsZQ%3D%3D?line=50'>51</a> results1 = session.run(query_paper)
#      <a href='vscode-notebook-cell:/c%3A/Users/ALANDASTU/Dropbox/WORKING/neo4j_jupyters/Batches2Neo4j.ipynb#W6sZmlsZQ%3D%3D?line=52'>53</a> # add organisations
#      <a href='vscode-notebook-cell:/c%3A/Users/ALANDASTU/Dropbox/WORKING/neo4j_jupyters/Batches2Neo4j.ipynb#W6sZmlsZQ%3D%3D?line=53'>54</a> query_organisation = query_p1 + query_p3
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\work\session.py:300, in Session.run(self, query, parameters, **kwargs)
#     296     raise ClientError("Explicit Transaction must be handled explicitly")
#     298 if self._auto_result:
#     299     # This will buffer upp all records for the previous auto-commit tx
# --> 300     self._auto_result._buffer_all()
#     302 if not self._connection:
#     303     self._connect(self._config.default_access_mode)
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\work\result.py:305, in Result._buffer_all(self)
#     301 def _buffer_all(self):
#     302     """Sets the Result object in an detached state by fetching all records
#     303     from the connection to the buffer.
#     304     """
# --> 305     self._buffer()
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\work\result.py:291, in Result._buffer(self, n)
#     289     return
#     290 record_buffer = deque()
# --> 291 for record in self:
#     292     record_buffer.append(record)
#     293     if n is not None and len(record_buffer) >= n:
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\work\result.py:251, in Result.__iter__(self)
#     249     yield self._record_buffer.popleft()
#     250 elif self._streaming:
# --> 251     self._connection.fetch_message()
#     252 elif self._discarding:
#     253     self._discard()
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\io\_common.py:180, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     178 def inner(*args, **kwargs):
#     179     try:
# --> 180         func(*args, **kwargs)
#     181     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     182         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\io\_bolt.py:848, in Bolt.fetch_message(self)
#     845     return 0, 0
#     847 # Receive exactly one message
# --> 848 tag, fields = self.inbox.pop(
#     849     hydration_hooks=self.responses[0].hydration_hooks
#     850 )
#     851 res = self._process_message(tag, fields)
#     852 self.idle_since = perf_counter()
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\io\_common.py:74, in Inbox.pop(self, hydration_hooks)
#      73 def pop(self, hydration_hooks):
# ---> 74     self._buffer_one_chunk()
#      75     try:
#      76         size, tag = self._unpacker.unpack_structure_header()
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\io\_common.py:53, in Inbox._buffer_one_chunk(self)
#      50 while True:
#      51     while chunk_size == 0:
#      52         # Determine the chunk size and skip noop
# ---> 53         receive_into_buffer(self._socket, self._buffer, 2)
#      54         chunk_size = self._buffer.pop_u16()
#      55         if chunk_size == 0:
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_sync\io\_common.py:308, in receive_into_buffer(sock, buffer, n_bytes)
#     306 with memoryview(buffer.data) as view:
#     307     while buffer.used < end:
# --> 308         n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#     309         if n == 0:
#     310             raise OSError("No data")
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:488, in BoltSocket.recv_into(self, buffer, nbytes)
#     487 def recv_into(self, buffer, nbytes):
# --> 488     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
# File d:\environments\genephys\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:463, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#     461 def _wait_for_io(self, func, *args, **kwargs):
#     462     if self._deadline is None:
# --> 463         return func(*args, **kwargs)
#     464     timeout = self._socket.gettimeout()
#     465     deadline_timeout = self._deadline.to_timeout()
#
# KeyboardInterrupt:

# %%
results1.data()
# Out:
# [{'paper': {'code': '10.1108/jhtt-12-2018-0118',
#    'name': ['Artificial intelligence and big data in tourism: a systematic literature review'],
#    'url': 'http://dx.doi.org/10.1108/jhtt-12-2018-0118',
#    'doi': '10.1108/jhtt-12-2018-0118'}},
#  {'paper': {'code': '10.2118/204672-ms',
#    'name': ['Geomechanical Properties Estimation Utilizing Artificial Intelligence Prediction Tool'],
#    'url': 'http://dx.doi.org/10.2118/204672-ms',
#    'doi': '10.2118/204672-ms'}},
#  {'paper': {'code': '10.20965/ijat.2023.p0091',
#    'name': ['Special Issue on Application of Artificial Intelligence Techniques in Production Engineering'],
#    'url': 'http://dx.doi.org/10.20965/ijat.2023.p0091',
#    'doi': '10.20965/ijat.2023.p0091'}},
#  {'paper': {'code': '10.1142/s0219265921430192',
#    'name': ['Research on the Control Method of Unmanned Helicopter Under the Background of Artificial Intelligence'],
#    'url': 'http://dx.doi.org/10.1142/s0219265921430192',
#    'doi': '10.1142/s0219265921430192'}},
#  {'paper': {'code': '10.1108/lht-12-2017-0274',
#    'name': ['Artificial Intelligence powered Internet of Things and smart public service'],
#    'url': 'http://dx.doi.org/10.1108/lht-12-2017-0274',
#    'doi': '10.1108/lht-12-2017-0274'}},
#  {'paper': {'code': '10.3390/biomedicines9020159',
#    'name': ['Proteomic Profiling and Artificial Intelligence for Hepatocellular Carcinoma Translational Medicine'],
#    'url': 'http://dx.doi.org/10.3390/biomedicines9020159',
#    'doi': '10.3390/biomedicines9020159'}},
#  {'paper': {'code': '10.1093/eurpub/ckab164.731',
#    'name': ['Artificial Intelligence and Urban health: a step forward to the achievement of SDGs'],
#    'url': 'http://dx.doi.org/10.1093/eurpub/ckab164.731',
#    'doi': '10.1093/eurpub/ckab164.731'}},
#  {'paper': {'code': '10.3390/antibiotics11060784',
#    'name': ['Application of Artificial Intelligence in Combating High Antimicrobial Resistance Rates'],
#    'url': 'http://dx.doi.org/10.3390/antibiotics11060784',
#    'doi': '10.3390/antibiotics11060784'}},
#  {'paper': {'code': '10.1108/jices-03-2020-0034',
#    'name': ['An exploration of the impact of artificial intelligence (AI) and automation for communication professionals'],
#    'url': 'http://dx.doi.org/10.1108/jices-03-2020-0034',
#    'doi': '10.1108/jices-03-2020-0034'}},
#  {'paper': {'code': '10.2196/28921',
#    'name': ['Ethical Applications of Artificial Intelligence: Evidence From Health Research on Veterans'],
#    'url': 'http://dx.doi.org/10.2196/28921',
#    'doi': '10.2196/28921'}},
#  {'paper': {'code': '10.1038/s43856-022-00214-4',
#    'name': ['Mitigating the impact of biased artificial intelligence in emergency decision-making'],
#    'url': 'http://dx.doi.org/10.1038/s43856-022-00214-4',
#    'doi': '10.1038/s43856-022-00214-4'}},
#  {'paper': {'code': '10.1115/97-gt-442',
#    'name': ['Use of Artificial Neural Networks for the Simulation of Combined Cycle Transients'],
#    'url': 'http://dx.doi.org/10.1115/97-gt-442',
#    'doi': '10.1115/97-gt-442'}},
#  {'paper': {'code': '10.21272/mmi.2021.1-07',
#    'name': ['Artificial Intelligence for marketing plan: the case for e-marketing companies'],
#    'url': 'http://dx.doi.org/10.21272/mmi.2021.1-07',
#    'doi': '10.21272/mmi.2021.1-07'}},
#  {'paper': {'code': '10.1186/s40662-021-00273-z',
#    'name': ['Application of artificial intelligence in cataract management: current and future directions'],
#    'url': 'http://dx.doi.org/10.1186/s40662-021-00273-z',
#    'doi': '10.1186/s40662-021-00273-z'}},
#  {'paper': {'code': '10.54941/ahfe1001432',
#    'name': ['Impact of Artificial Intelligence in the Certification of Human-Centered Aviation systems'],
#    'url': 'http://dx.doi.org/10.54941/ahfe1001432',
#    'doi': '10.54941/ahfe1001432'}},
#  {'paper': {'code': '10.35854/1998-1627-2023-3-280-287',
#    'name': ['Major obstacles and directions for the application of artificial intelligence in international business'],
#    'url': 'http://dx.doi.org/10.35854/1998-1627-2023-3-280-287',
#    'doi': '10.35854/1998-1627-2023-3-280-287'}},
#  {'paper': {'code': '10.1038/s41746-023-00829-4',
#    'name': ['The impact of artificial intelligence on the reading times of radiologists for chest radiographs'],
#    'url': 'http://dx.doi.org/10.1038/s41746-023-00829-4',
#    'doi': '10.1038/s41746-023-00829-4'}},
#  {'paper': {'code': '10.2118/194807-ms',
#    'name': ['Real-Time Drilling Models Monitoring Using Artificial Intelligence'],
#    'url': 'http://dx.doi.org/10.2118/194807-ms',
#    'doi': '10.2118/194807-ms'}},
#  {'paper': {'code': '10.1098/rsos.191649',
#    'name': ['Peer-to-peer loan acceptance and default prediction with artificial intelligence'],
#    'url': 'http://dx.doi.org/10.1098/rsos.191649',
#    'doi': '10.1098/rsos.191649'}},
#  {'paper': {'code': '10.1159/000512438',
#    'name': ['Artificial Intelligence-Based Polyp Detection in Colonoscopy: Where Have We Been, Where Do We Stand, and Where Are We Headed?'],
#    'url': 'http://dx.doi.org/10.1159/000512438',
#    'doi': '10.1159/000512438'}},
#  {'paper': {'code': '10.54941/ahfe1002702',
#    'name': ['Cyber-Physical Behaviour Detection and Understanding using Artificial Intelligence'],
#    'url': 'http://dx.doi.org/10.54941/ahfe1002702',
#    'doi': '10.54941/ahfe1002702'}},
#  {'paper': {'code': '10.2196/preprints.36890',
#    'name': ['The Role of Standards in Accelerating the Uptake of Artificial Intelligence in Dermatology (Preprint)'],
#    'url': 'http://dx.doi.org/10.2196/preprints.36890',
#    'doi': '10.2196/preprints.36890'}},
#  {'paper': {'code': '10.32628/ijsrst229490',
#    'name': ['Methods of Air Traffic Management Using Artificial Intelligence in India'],
#    'url': 'http://dx.doi.org/10.32628/ijsrst229490',
#    'doi': '10.32628/ijsrst229490'}},
#  {'paper': {'code': '10.31219/osf.io/3t9zc',
#    'name': ['An Artificial Intelligence Driven System  to Predict ASD Outcomes in ABA'],
#    'url': 'http://dx.doi.org/10.31219/osf.io/3t9zc',
#    'doi': '10.31219/osf.io/3t9zc'}},
#  {'paper': {'code': '10.1088/1742-6596/1986/1/012078',
#    'name': ['Intelligent Service Scheduling Decision Technology under Artificial Intelligence Technology'],
#    'url': 'http://dx.doi.org/10.1088/1742-6596/1986/1/012078',
#    'doi': '10.1088/1742-6596/1986/1/012078'}},
#  {'paper': {'code': '10.3390/rs14174421',
#    'name': ['Implementation of an Artificial Intelligence Approach to GPR Systems for Landmine Detection'],
#    'url': 'http://dx.doi.org/10.3390/rs14174421',
#    'doi': '10.3390/rs14174421'}},
#  {'paper': {'code': '10.1093/toxsci/kfac101',
#    'name': ['Machine learning and artificial intelligence in physiologically based pharmacokinetic modeling'],
#    'url': 'http://dx.doi.org/10.1093/toxsci/kfac101',
#    'doi': '10.1093/toxsci/kfac101'}},
#  {'paper': {'code': '10.2174/2213275912666190212124133',
#    'name': ['Power Transformer Fault Diagnosis using DGA and Artificial Intelligence'],
#    'url': 'http://dx.doi.org/10.2174/2213275912666190212124133',
#    'doi': '10.2174/2213275912666190212124133'}},
#  {'paper': {'code': '10.34190/ecel.21.1.661',
#    'name': ['Artificial Intelligence to improve learning outcomes through online collaborative activities'],
#    'url': 'http://dx.doi.org/10.34190/ecel.21.1.661',
#    'doi': '10.34190/ecel.21.1.661'}},
#  {'paper': {'code': '10.21203/rs.3.rs-614881/v1',
#    'name': ['Impact of Artificial Intelligence, With and Without Information, on Pathologists’ Decisions: An Experiment'],
#    'url': 'http://dx.doi.org/10.21203/rs.3.rs-614881/v1',
#    'doi': '10.21203/rs.3.rs-614881/v1'}}]

# %%
driver.close()  # close the driver object
